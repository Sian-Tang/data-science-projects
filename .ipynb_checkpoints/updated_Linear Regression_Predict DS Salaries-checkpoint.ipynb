# %% [markdown]
# # Predicting Data Science Salaries - Linear Regression
#
# ### Pretext
# Updating the linear regression model of my previous attempt.
#
# Now that I have more knowledge and understanding of the topic machine learning and the fundamentals of data, I expect a better prediction model

# %% [markdown]
# ### Code
# We want to predict the salary of data scientists using a general linear regression model.
#
# #### Data
# - Data file name: `ds_salaries.csv`
# - source: n/a
# - downloaded: n/a

# %% [markdown]
# #### Import packages

# %%
# basic packages
import pandas as pd
import numpy as np
# plots and visuals
import matplotlib.pyplot as plt
import seaborn as sns
# machine learning model
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from yellowbrick.regressor import ResidualsPlot
# statistical tests
from scipy.stats import chi2_contingency, ttest_ind, f_oneway
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# shows more columns
pd.set_option('display.max_columns', 500)

# %% [markdown]
# #### Read data

# %%
raw_data = pd.read_csv("ds_salaries.csv")
data = raw_data.copy()

# %% [markdown]
# ### Initial Data Inspection
# We start by doing an initial data inspection to get a feel on the data before we do some analysis and modelling.
#
# #### Size of Data

# %%
num_rows, num_cols = data.shape
print('The data has {} rows and {} columns'.format(num_rows, num_cols))
# Out:
# The data has 607 rows and 12 columns

# %% [markdown]
# #### Basic info about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# #### Data Types

# %%
# data types
data.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# #### First look on data

# %%
# show first five rows
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
# show last five rows
data.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L

# %% [markdown]
# #### Statistical info about data

# %%
data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# #### Check for missing values

# %%
data.isnull().any()
# Out:
# Unnamed: 0            False
# work_year             False
# experience_level      False
# employment_type       False
# job_title             False
# salary                False
# salary_currency       False
# salary_in_usd         False
# employee_residence    False
# remote_ratio          False
# company_location      False
# company_size          False
# dtype: bool

# %% [markdown]
# #### Check for duplicate entries

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
data = data.drop_duplicates()
num_rows_new, num_cols_new = data.shape
print('The data with duplicates has {} rows and {} columns'.format(num_rows, num_cols))
print('The data w/o duplicates had {} rows and {} columns'.format(num_rows_new, num_cols_new))
# Out:
# The data with duplicates has 607 rows and 12 columns
# The data w/o duplicates had 607 rows and 12 columns

# %% [markdown]
# #### Unique values

# %%
data.nunique()
# Out:
# Unnamed: 0            607
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %% [markdown]
# #### Remove unnecessary columns

# %%
data = data.drop(['Unnamed: 0', 'salary', 'salary_currency', 'employee_residence'], axis = 1)

num_rows, num_cols = data.shape
print('The data has {} rows and {} columns'.format(num_rows, num_cols))
# Out:
# The data has 607 rows and 8 columns

# %% [markdown]
# ### Data Visualization

# %%
# get all numerical data columns
numeric_columns = data.select_dtypes(include=['int64', 'float64'])

print('The numeric data has {} rows and {} columns'.format(numeric_columns.shape[0], numeric_columns.shape[1]))

# Print the numerical columns
numeric_columns
# Out:
# The numeric data has 607 rows and 3 columns
#      work_year  salary_in_usd  remote_ratio
# 0         2020          79833             0
# 1         2020         260000             0
# 2         2020         109024            50
# 3         2020          20000             0
# 4         2020         150000            50
# ..         ...            ...           ...
# 602       2022         154000           100
# 603       2022         126000           100
# 604       2022         129000             0
# 605       2022         150000           100
# 606       2022         200000           100
#
# [607 rows x 3 columns]

# %% [markdown]
# #### Boxplot - numeric columns

# %%
# Create a figure with a grid of subplots
fig, axs = plt.subplots(1, len(numeric_columns.columns), figsize=(15, 5))

# Iterate over the columns and create a boxplot for each one
for i, col in enumerate(numeric_columns.columns):
    ax = axs[i]
    ax.boxplot(numeric_columns[col])
    ax.set_title(col)

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Statistical description per category

# %%
data.loc[(data['salary_in_usd'] > 300000)]
# Out:
#      work_year experience_level employment_type  \
# 25        2020               EX              FT
# 33        2020               MI              FT
# 63        2020               SE              FT
# 97        2021               MI              FT
# 157       2021               MI              FT
# 225       2021               EX              CT
# 252       2021               EX              FT
# 482       2022               EX              FT
# 519       2022               SE              FT
# 523       2022               SE              FT
#
#                               job_title  salary_in_usd  remote_ratio  \
# 25             Director of Data Science         325000           100
# 33                   Research Scientist         450000             0
# 63                       Data Scientist         412000           100
# 97               Financial Data Analyst         450000           100
# 157  Applied Machine Learning Scientist         423000            50
# 225            Principal Data Scientist         416000           100
# 252             Principal Data Engineer         600000           100
# 482                       Data Engineer         324000           100
# 519              Applied Data Scientist         380000           100
# 523                 Data Analytics Lead         405000           100
#
#     company_location company_size
# 25                US            L
# 33                US            M
# 63                US            L
# 97                US            L
# 157               US            L
# 225               US            S
# 252               US            L
# 482               US            M
# 519               US            L
# 523               US            L

# %%
data.loc[data['experience_level'] == 'EX']
# Out:
#      work_year experience_level employment_type                 job_title  \
# 25        2020               EX              FT  Director of Data Science
# 41        2020               EX              FT  Data Engineering Manager
# 73        2021               EX              FT           BI Data Analyst
# 74        2021               EX              FT              Head of Data
# 84        2021               EX              FT  Director of Data Science
# 160       2021               EX              FT              Head of Data
# 161       2021               EX              FT      Head of Data Science
# 164       2021               EX              FT  Director of Data Science
# 167       2021               EX              FT  Director of Data Science
# 187       2021               EX              FT   Data Science Consultant
# 225       2021               EX              CT  Principal Data Scientist
# 252       2021               EX              FT   Principal Data Engineer
# 259       2021               EX              FT  Director of Data Science
# 309       2022               EX              FT             Data Engineer
# 310       2022               EX              FT             Data Engineer
# 326       2022               EX              FT              Data Analyst
# 327       2022               EX              FT              Data Analyst
# 342       2022               EX              FT      Head of Data Science
# 343       2022               EX              FT      Head of Data Science
# 344       2022               EX              FT        Analytics Engineer
# 368       2022               EX              FT        Analytics Engineer
# 375       2022               EX              FT        Lead Data Engineer
# 384       2022               EX              FT  Head of Machine Learning
# 452       2022               EX              FT  Director of Data Science
# 482       2022               EX              FT             Data Engineer
# 483       2022               EX              FT             Data Engineer
#
#      salary_in_usd  remote_ratio company_location company_size
# 25          325000           100               US            L
# 41           79833            50               ES            L
# 73          150000           100               US            L
# 74          235000           100               US            L
# 84          153667           100               PL            L
# 160         230000            50               RU            L
# 161          85000             0               RU            M
# 164         130026            50               DE            M
# 167         250000             0               US            L
# 187          69741           100               ES            S
# 225         416000           100               US            S
# 252         600000           100               US            L
# 259         141846             0               DE            L
# 309         242000           100               US            M
# 310         200000           100               US            M
# 326         130000           100               US            M
# 327         110000           100               US            M
# 342         224000           100               US            M
# 343         167875           100               US            M
# 344         175000           100               US            M
# 368         135000           100               US            M
# 375         118187           100               CA            S
# 384          79039            50               IN            L
# 452         196979            50               CA            L
# 482         324000           100               US            M
# 483         216000           100               US            M

# %%
data.groupby(['work_year']).describe()
# Out:
#           salary_in_usd                                                 \
#                   count           mean           std      min      25%
# work_year
# 2020               72.0   95813.000000  82831.799222   5707.0  45724.5
# 2021              217.0   99853.792627  80225.106319   2859.0  50000.0
# 2022              318.0  124522.006289  58183.647585  10000.0  81666.0
#
#                                         remote_ratio                        \
#                 50%       75%       max        count       mean        std
# work_year
# 2020        75544.0  115526.0  450000.0         72.0  64.583333  39.750543
# 2021        82528.0  135000.0  600000.0        217.0  69.124424  37.151694
# 2022       120000.0  160000.0  405000.0        318.0  73.584906  43.072575
#
#
#            min   25%    50%    75%    max
# work_year
# 2020       0.0  50.0   75.0  100.0  100.0
# 2021       0.0  50.0  100.0  100.0  100.0
# 2022       0.0  50.0  100.0  100.0  100.0

# %%
data.groupby('experience_level').describe()
# Out:
#                  work_year                                                 \
#                      count         mean       std     min     25%     50%
# experience_level
# EN                    88.0  2021.011364  0.686392  2020.0  2021.0  2021.0
# EX                    26.0  2021.423077  0.643309  2020.0  2021.0  2021.5
# MI                   213.0  2021.276995  0.709296  2020.0  2021.0  2021.0
# SE                   280.0  2021.625000  0.603529  2020.0  2021.0  2022.0
#
#                                  salary_in_usd                                \
#                      75%     max         count           mean            std
# experience_level
# EN                2021.0  2022.0          88.0   61643.318182   44395.541126
# EX                2022.0  2022.0          26.0  199392.038462  117071.255697
# MI                2022.0  2022.0         213.0   87996.056338   63901.057478
# SE                2022.0  2022.0         280.0  138617.292857   57691.978337
#
#                                                                     \
#                       min       25%       50%        75%       max
# experience_level
# EN                 4000.0   27505.0   56500.0   85425.75  250000.0
# EX                69741.0  130006.5  171437.5  233750.00  600000.0
# MI                 2859.0   48000.0   76940.0  112000.00  450000.0
# SE                18907.0  100000.0  135500.0  170000.00  412000.0
#
#                  remote_ratio                                                 \
#                         count       mean        std  min   25%    50%    75%
# experience_level
# EN                       88.0  69.886364  37.554384  0.0  50.0  100.0  100.0
# EX                       26.0  78.846154  35.137094  0.0  50.0  100.0  100.0
# MI                      213.0  63.849765  42.705839  0.0   0.0  100.0  100.0
# SE                      280.0  75.892857  39.927209  0.0  50.0  100.0  100.0
#
#
#                     max
# experience_level
# EN                100.0
# EX                100.0
# MI                100.0
# SE                100.0

# %%
data.groupby('employment_type').describe()
# Out:
#                 work_year                                                  \
#                     count         mean       std     min      25%     50%
# employment_type
# CT                    5.0  2021.000000  0.707107  2020.0  2021.00  2021.0
# FL                    4.0  2021.000000  0.816497  2020.0  2020.75  2021.0
# FT                  588.0  2021.418367  0.689520  2020.0  2021.00  2022.0
# PT                   10.0  2021.000000  0.666667  2020.0  2021.00  2021.0
#
#                                  salary_in_usd                                \
#                      75%     max         count           mean            std
# employment_type
# CT               2021.00  2022.0           5.0  184575.000000  156250.889997
# FL               2021.25  2022.0           4.0   48000.000000   40529.824410
# FT               2022.00  2022.0         588.0  113468.073129   69476.470098
# PT               2021.00  2022.0          10.0   33070.500000   31472.907966
#
#                                                                    \
#                      min        25%       50%       75%       max
# employment_type
# CT               31875.0  100000.00  105000.0  270000.0  416000.0
# FL               12000.0   18000.00   40000.0   70000.0  100000.0
# FT                2859.0   64962.25  104196.5  150000.0  600000.0
# PT                5409.0   12000.00   18817.5   48370.0  100000.0
#
#                 remote_ratio                                              \
#                        count        mean        std    min    25%    50%
# employment_type
# CT                       5.0  100.000000   0.000000  100.0  100.0  100.0
# FL                       4.0   62.500000  47.871355    0.0   37.5   75.0
# FT                     588.0   70.748299  41.002571    0.0   50.0  100.0
# PT                      10.0   70.000000  25.819889   50.0   50.0   50.0
#
#
#                    75%    max
# employment_type
# CT               100.0  100.0
# FL               100.0  100.0
# FT               100.0  100.0
# PT               100.0  100.0

# %%
data.groupby('company_size').describe()
# Out:
#              work_year                                                         \
#                  count         mean       std     min     25%     50%     75%
# company_size
# L                198.0  2021.065657  0.629827  2020.0  2021.0  2021.0  2021.0
# M                326.0  2021.751534  0.522933  2020.0  2022.0  2022.0  2022.0
# S                 83.0  2020.855422  0.665024  2020.0  2020.0  2021.0  2021.0
#
#                      salary_in_usd                                       \
#                  max         count           mean           std     min
# company_size
# L             2022.0         198.0  119242.994949  86156.740692  5882.0
# M             2022.0         326.0  116905.466258  59287.694614  4000.0
# S             2022.0          83.0   77632.674699  63461.706497  2859.0
#
#                                                      remote_ratio             \
#                    25%       50%       75%       max        count       mean
# company_size
# L             61041.75  100000.0  154600.0  600000.0        198.0  68.686869
# M             78131.50  113188.0  152875.0  450000.0        326.0  72.546012
# S             41943.00   65000.0  100000.0  416000.0         83.0  69.879518
#
#
#                     std  min   25%    50%    75%    max
# company_size
# L             37.420548  0.0  50.0  100.0  100.0  100.0
# M             42.851687  0.0  50.0  100.0  100.0  100.0
# S             39.770499  0.0  50.0  100.0  100.0  100.0

# %%
data.groupby('job_title').mean()
# Out:
#                                             work_year  salary_in_usd  \
# job_title
# 3D Computer Vision Researcher             2021.000000    5409.000000
# AI Scientist                              2021.142857   66135.571429
# Analytics Engineer                        2022.000000  175000.000000
# Applied Data Scientist                    2021.600000  175655.000000
# Applied Machine Learning Scientist        2021.500000  142068.750000
# BI Data Analyst                           2020.833333   74755.166667
# Big Data Architect                        2021.000000   99703.000000
# Big Data Engineer                         2020.625000   51974.000000
# Business Data Analyst                     2021.000000   76691.200000
# Cloud Data Engineer                       2021.000000  124647.000000
# Computer Vision Engineer                  2021.166667   44419.333333
# Computer Vision Software Engineer         2021.333333  105248.666667
# Data Analyst                              2021.680412   92893.061856
# Data Analytics Engineer                   2021.250000   64799.250000
# Data Analytics Lead                       2022.000000  405000.000000
# Data Analytics Manager                    2021.571429  127134.285714
# Data Architect                            2021.727273  177873.909091
# Data Engineer                             2021.590909  112725.000000
# Data Engineering Manager                  2020.600000  123227.200000
# Data Science Consultant                   2020.714286   69420.714286
# Data Science Engineer                     2021.333333   75803.333333
# Data Science Manager                      2021.333333  158328.500000
# Data Scientist                            2021.391608  108187.832168
# Data Specialist                           2021.000000  165000.000000
# Director of Data Engineering              2021.000000  156738.000000
# Director of Data Science                  2021.000000  195074.000000
# ETL Developer                             2022.000000   54957.000000
# Finance Data Analyst                      2021.000000   61896.000000
# Financial Data Analyst                    2021.500000  275000.000000
# Head of Data                              2021.400000  160162.600000
# Head of Data Science                      2021.500000  146718.750000
# Head of Machine Learning                  2022.000000   79039.000000
# Lead Data Analyst                         2020.666667   92203.000000
# Lead Data Engineer                        2020.833333  139724.500000
# Lead Data Scientist                       2020.333333  115190.000000
# Lead Machine Learning Engineer            2022.000000   87932.000000
# ML Engineer                               2021.000000  117504.000000
# Machine Learning Developer                2021.666667   85860.666667
# Machine Learning Engineer                 2021.317073  104880.146341
# Machine Learning Infrastructure Engineer  2021.000000  101145.000000
# Machine Learning Manager                  2020.000000  117104.000000
# Machine Learning Scientist                2021.250000  158412.500000
# Marketing Data Analyst                    2021.000000   88654.000000
# NLP Engineer                              2022.000000   37236.000000
# Principal Data Analyst                    2021.500000  122500.000000
# Principal Data Engineer                   2021.000000  328333.333333
# Principal Data Scientist                  2021.000000  215242.428571
# Product Data Analyst                      2020.000000   13036.000000
# Research Scientist                        2021.125000  109019.500000
# Staff Data Scientist                      2021.000000  105000.000000
#
#                                           remote_ratio
# job_title
# 3D Computer Vision Researcher                50.000000
# AI Scientist                                 78.571429
# Analytics Engineer                           50.000000
# Applied Data Scientist                       70.000000
# Applied Machine Learning Scientist           87.500000
# BI Data Analyst                              66.666667
# Big Data Architect                           50.000000
# Big Data Engineer                            50.000000
# Business Data Analyst                        90.000000
# Cloud Data Engineer                          75.000000
# Computer Vision Engineer                     58.333333
# Computer Vision Software Engineer           100.000000
# Data Analyst                                 75.257732
# Data Analytics Engineer                      75.000000
# Data Analytics Lead                         100.000000
# Data Analytics Manager                       85.714286
# Data Architect                              100.000000
# Data Engineer                                75.000000
# Data Engineering Manager                     70.000000
# Data Science Consultant                      71.428571
# Data Science Engineer                        83.333333
# Data Science Manager                         83.333333
# Data Scientist                               63.986014
# Data Specialist                             100.000000
# Director of Data Engineering                100.000000
# Director of Data Science                     42.857143
# ETL Developer                                 0.000000
# Finance Data Analyst                         50.000000
# Financial Data Analyst                       75.000000
# Head of Data                                 90.000000
# Head of Data Science                         50.000000
# Head of Machine Learning                     50.000000
# Lead Data Analyst                           100.000000
# Lead Data Engineer                           66.666667
# Lead Data Scientist                          50.000000
# Lead Machine Learning Engineer                0.000000
# ML Engineer                                  83.333333
# Machine Learning Developer                   83.333333
# Machine Learning Engineer                    67.073171
# Machine Learning Infrastructure Engineer     50.000000
# Machine Learning Manager                     50.000000
# Machine Learning Scientist                   68.750000
# Marketing Data Analyst                      100.000000
# NLP Engineer                                 50.000000
# Principal Data Analyst                      100.000000
# Principal Data Engineer                     100.000000
# Principal Data Scientist                     85.714286
# Product Data Analyst                         50.000000
# Research Scientist                           53.125000
# Staff Data Scientist                        100.000000

# %% [markdown]
# Get rid of job title that only appear once in the dataset
#
# On second thought, it may be wise to leave them in. Otherwise there could be trouble with testing.
#
# But it's good to know how to do it, so I will leave the code snippet in but not use it :)

# %%
# Group the data by job_title
job_title_counts = data.groupby('job_title').size()

# Convert the result into a DataFrame
job_title_counts = job_title_counts.reset_index(name = 'size')

# Select the rows with size > 1
frequent_job_titles = job_title_counts.loc[job_title_counts['size'] > 1]

# Reset the index and drop the old index column
frequent_job_titles = frequent_job_titles.reset_index(drop = True)

# Use the resulting DataFrame to select the rows from the original data
filtered_data = data[data['job_title'].isin(frequent_job_titles['job_title'])]

filtered_data.reset_index()
# Out:
#      index  work_year experience_level employment_type  \
# 0        0       2020               MI              FT
# 1        1       2020               SE              FT
# 2        2       2020               SE              FT
# 3        3       2020               MI              FT
# 4        4       2020               SE              FT
# ..     ...        ...              ...             ...
# 591    602       2022               SE              FT
# 592    603       2022               SE              FT
# 593    604       2022               SE              FT
# 594    605       2022               SE              FT
# 595    606       2022               MI              FT
#
#                       job_title  salary_in_usd  remote_ratio company_location  \
# 0                Data Scientist          79833             0               DE
# 1    Machine Learning Scientist         260000             0               JP
# 2             Big Data Engineer         109024            50               GB
# 3          Product Data Analyst          20000             0               HN
# 4     Machine Learning Engineer         150000            50               US
# ..                          ...            ...           ...              ...
# 591               Data Engineer         154000           100               US
# 592               Data Engineer         126000           100               US
# 593                Data Analyst         129000             0               US
# 594                Data Analyst         150000           100               US
# 595                AI Scientist         200000           100               US
#
#     company_size
# 0              L
# 1              S
# 2              M
# 3              S
# 4              L
# ..           ...
# 591            M
# 592            M
# 593            M
# 594            M
# 595            L
#
# [596 rows x 9 columns]

# %%
# Check specific data entry 
data.iloc[225]
# Out:
# work_year                               2021
# experience_level                          EX
# employment_type                           CT
# job_title           Principal Data Scientist
# salary_in_usd                         416000
# remote_ratio                             100
# company_location                          US
# company_size                               S
# Name: 225, dtype: object

# %%
numeric_columns = data.select_dtypes(include=['int64', 'float64'])

# %%
# Create a figure with a grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Iterate over the columns and create a boxplot for each one
for i, col in enumerate(numeric_columns.columns):
    ax = axs[i]
    ax.boxplot(numeric_columns[col])
    ax.set_title(col)

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# When looking at the boxplot of `salary_in_usd` I am considering to remove all the outlier points (> 300.000) as they will significantly influence the regression line, although they only contribute to a small proportion of the dataset.

# %% [markdown]
# #### Remove outliers of `salary_in_usd`

# %%
# Select only the rows with salary_in_usd less than or equal to 500000
data = data.loc[data['salary_in_usd'] <= 300000]

# %%
numeric_columns = data.select_dtypes(include=['int64', 'float64'])
# Create a figure with a grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Iterate over the columns and create a boxplot for each one
for i, col in enumerate(numeric_columns.columns):
    ax = axs[i]
    ax.boxplot(numeric_columns[col])
    ax.set_title(col)

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Boxplot - nominal columns

# %%
# get all nominal columns
nominal_columns = data.select_dtypes(include='object')

# %%
# Use the loc method to filter the Series and get the names of the columns with less than XX unique values
cols_with_few_unique_values = data.nunique().loc[lambda x: x < 50].index

columns = cols_with_few_unique_values

# Create a figure with 3 subplots
fig, axs = plt.subplots(len(columns), 1, figsize=(4, 12))

# Loop through the columns and create a scatter plot with a fitted regression line for each column
for ax, column in zip(axs, columns):
    sns.boxplot(x=column, y='salary_in_usd', data=data, ax=ax)
    
    if data[column].nunique() > 10:
        # Rotate the x-axis labels by 90 degrees
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)


# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sian-\AppData\Local\Temp\ipykernel_7448\567580454.py:19: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# #### Histogram

# %%
# Create a figure with a grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Iterate over the columns and create a histogram for each one
for i, col in enumerate(numeric_columns.columns):
    ax = axs[i]
    if col == "work_year":
        ax.hist(numeric_columns[col], bins = [2019.5,2020.5,2021.5,2022.5], rwidth=0.5)
        ax.set_xticks([2020,2021,2022])
        ax.set_xticklabels([2020,2021,2022])
    else:
        ax.hist(numeric_columns[col], rwidth = 0.9)
    ax.set_title(col)

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %%
corr = data.corr()

sns.heatmap(corr, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot: >

# %%
columns = numeric_columns.columns

# Create a figure with 3 subplots
fig, axs = plt.subplots(len(columns), 1, figsize=(4, 12))

# Loop through the columns and create a scatter plot with a fitted regression line for each column
for ax, column in zip(axs, columns):
    sns.regplot(x=column, y='salary_in_usd', data=data, ax=ax)
    
    # Calculate the Pearson correlation coefficient
    corr = data[column].corr(data['salary_in_usd'])
    
    # Set the title for the plot
    ax.set_title(f'{column}: Correlation = {corr}')


# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Statistical Tests

# %% [markdown]
# #### Chi-Squared test
# The chi-squared test is a statistical test that measures the association between two categorical variables. It can be used to test whether there is a significant difference between the observed frequencies of the categories in the two variables, or whether the two variables are independent of each other.

# %%
for column in nominal_columns:
    # Create a contingency table of the column and salary_in_usd
    contingency_table = pd.crosstab(column, data['salary_in_usd'])

    # Perform the chi-squared test
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    print(f'chi2 for {column} and salary_in_usd: {chi2}')
    print(f'p for {column} and salary_in_usd: {p}\n')
# Out:
# chi2 for experience_level and salary_in_usd: 0.0
# p for experience_level and salary_in_usd: 1.0
#
# chi2 for employment_type and salary_in_usd: 0.0
# p for employment_type and salary_in_usd: 1.0
#
# chi2 for job_title and salary_in_usd: 0.0
# p for job_title and salary_in_usd: 1.0
#
# chi2 for company_location and salary_in_usd: 0.0
# p for company_location and salary_in_usd: 1.0
#
# chi2 for company_size and salary_in_usd: 0.0
# p for company_size and salary_in_usd: 1.0

# %% [markdown]
# .. Yeah **chi-squared** is only used on **two categorical columns**. In my case I used categorical column with a numerical column -> hence the lack of significance.

# %% [markdown]
# #### t-test

# %%
nominal_columns
# Out:
#     experience_level employment_type                   job_title  \
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 3                 HN            S
# 4                 US            L
# ..               ...          ...
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L
#
# [606 rows x 5 columns]

# %%
# Get a list of all nominal columns
nominal_columns = data.select_dtypes(include='object')

# Loop through the nominal columns and perform a t-test with salary_in_usd
for column in nominal_columns:
    # Get the name of the column
    #column = nominal_columns.iloc[i]

    # Split the data into two groups based on the column
    group1 = data[data[column] == data[column].unique()[0]]['salary_in_usd']
    group2 = data[data[column] == data[column].unique()[1]]['salary_in_usd']

    # Perform the t-test
    t, p = ttest_ind(group1, group2)

    print(f't for {column} and salary_in_usd: {t}')
    print(f'p for {column} and salary_in_usd: {p}\n')
# Out:
# t for experience_level and salary_in_usd: -9.210292076278856
# p for experience_level and salary_in_usd: 9.45037295337636e-19
#
# t for employment_type and salary_in_usd: -2.3703751795374823
# p for employment_type and salary_in_usd: 0.018090541772906282
#
# t for job_title and salary_in_usd: -2.1294853652368255
# p for job_title and salary_in_usd: 0.034857457197543046
#
# t for company_location and salary_in_usd: -1.466575786347232
# p for company_location and salary_in_usd: 0.1522508126424419
#
# t for company_size and salary_in_usd: 3.9954712848939726
# p for company_size and salary_in_usd: 8.274556911961275e-05

# %% [markdown]
# ### Evaluation
# - experience_level: significant difference with good p-value (worth considering)
# - employment_type: significant difference with good p-value (worth considering)
# - job_title: significant difference with good p-value (worth considering)
# - company_location: insignifact with bad p-value (to be removed)
# - company_size: significant difference with good p-value (worth considering)

# %%
nominal_columns_old = nominal_columns.copy()
nominal_columns = nominal_columns.drop(['company_location'], axis=1)

# %% [markdown]
# #### ANOVA

# %%
# Create a box plot
sns.boxplot(data=data, x='company_location', y='salary_in_usd')

# Rotate the x-axis labels by 90 degrees
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Loop through the nominal columns
for column in nominal_columns:
    # Extract the data for each group
    group1 = data[data[column] == data[column].unique()[0]]['salary_in_usd']
    group2 = data[data[column] == data[column].unique()[1]]['salary_in_usd']
    group3 = data[data[column] == data[column].unique()[2]]['salary_in_usd']
    
    # Perform the ANOVA
    f_statistic, p_value = f_oneway(group1, group2, group3)
    
    print(f'F-statistic for {column}: {f_statistic}')
    print(f'p-value for {column}: {p_value}\n')
# Out:
# F-statistic for experience_level: 78.90773192453521
# p-value for experience_level: 5.022617582688174e-31
#
# F-statistic for employment_type: 9.847415641054647
# p-value for employment_type: 6.196196720628079e-05
#
# F-statistic for job_title: 5.531268252168708
# p-value for job_title: 0.004776954821047457
#
# F-statistic for company_size: 12.300837311082997
# p-value for company_size: 5.806512266700239e-06

# %%
#One-Way-Anova: Is there a significant difference between fighter's height based on the result of the competition??!
sns.boxplot(data=nominal_columns, x='result', y='height')

# %%
# ANOVA 

for column in nominal_columns:
    str1 = column
    str2 = 'salary_in_usd'
    
    formula = str2 + ' ~ ' + f'C({str1})'
    model = ols(formula, data).fit()
    aov_table = anova_lm(model, typ=2)
    
    print(aov_table,'\n')

    # Show the plot
    plt.show()
# Out:
#                            sum_sq     df          F        PR(>F)
# C(experience_level)  6.714309e+11    3.0  62.915838  2.150956e-35
# Residual             2.141492e+12  602.0        NaN           NaN
#
#                           sum_sq     df         F    PR(>F)
# C(employment_type)  1.051024e+11    3.0  7.788757  0.000041
# Residual            2.707821e+12  602.0       NaN       NaN
#
#                     sum_sq     df         F        PR(>F)
# C(job_title)  6.385509e+11   49.0  3.332271  4.961220e-12
# Residual      2.174372e+12  556.0       NaN           NaN
#
#                        sum_sq     df          F    PR(>F)
# C(company_size)  1.102652e+11    2.0  12.300837  0.000006
# Residual         2.702658e+12  603.0        NaN       NaN

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### Linear Regression

# %%
# Select the columns to use as features
feature_columns = ['experience_level', 'employment_type', 'company_size', 'job_title']

# Create a ColumnTransformer to preprocess the categorical and nominal columns
ct = ColumnTransformer(
    [('one_hot_encoder', OneHotEncoder(), feature_columns)],
    remainder='passthrough'
)

# Preprocess the data and split it into training and test sets
X = ct.fit_transform(data[feature_columns])
y = data['salary_in_usd']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Fit a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Evaluate the model on the test set
score = model.score(X_test, y_test)
print(f'R-squared score: {score}')
# Out:
# R-squared score: 0.14743625827186801

# %%
visualizer = ResidualsPlot(model)
visualizer.fit(X,y)
visualizer.poof()
# Out:
# <AxesSubplot: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
data_new = pd.DataFrame(columns=data.columns)

data_new = data_new.append({'experience_level': 'MI', 'employment_type': 'CT', 'company_size': 'S', 'job_title': 'ML Engineer'}, ignore_index=True)

# Preprocess the new data using the same ColumnTransformer that was used to preprocess the original data
new_X = ct.transform(data_new[feature_columns])

# Make predictions using the transformed model
predictions = model.predict(new_X)

predictions
# Out:
# C:\Users\sian-\AppData\Local\Temp\ipykernel_11468\2038563205.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_new = data_new.append({'experience_level': 'MI', 'employment_type': 'CT', 'company_size': 'S', 'job_title': 'ML Engineer'}, ignore_index=True)
# array([175563.1622374])

# %%
data.loc[(data['job_title'] == 'ML Engineer')]
# Out:
#      work_year experience_level employment_type    job_title  salary_in_usd  \
# 45        2020               EN              PT  ML Engineer          15966
# 78        2021               MI              CT  ML Engineer         270000
# 136       2021               MI              FT  ML Engineer          63711
# 137       2021               MI              FT  ML Engineer          77364
# 231       2021               SE              FT  ML Engineer         256000
# 449       2022               EN              FT  ML Engineer          21983
#
#      remote_ratio company_location company_size
# 45            100               DE            S
# 78            100               US            L
# 136            50               JP            S
# 137            50               JP            S
# 231           100               US            S
# 449           100               PT            L
